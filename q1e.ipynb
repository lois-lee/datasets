# %% [markdown]
# <a href="https://colab.research.google.com/github/lois-lee/datasets/blob/master/q1e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c256e5c-43e7-4283-be0d-e21ed340907f" name="files[]" multiple disabled />
#      <output id="result-4c256e5c-43e7-4283-be0d-e21ed340907f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
import sys


zeros = []
ones = []
distances_gen_0 = []
distances_gen_1 = []
count_zero = 0
count_ones = 0

with open("train.csv") as f:

# skip the line
    next(f)
    # parse and convert to int list
    for line in f:
        arr = []
        pixels = []
        matrix = line.split(',')
        ######################################################
        #### Get the digit and the vector of pixel values ####
        ######################################################
        
        if matrix[0] == '0':
            for x in matrix:
                x = x.split('\r\n')
                for p in x:
                    if p != '':
                        arr.append(int(p))
            digit = arr[0]
            pixel = np.array(arr[1:])
            zeros.append(pixel)
            count_zero = count_zero + 1
            
        if matrix[0] == '1':
            for x in matrix:
                x = x.split('\r\n')
                for p in x:
                    if p != '':
                        arr.append(int(p))
            digit = arr[0]
            pixel = np.array(arr[1:])
            ones.append(pixel)
            count_ones = count_ones + 1
        
    ######################################################
    ## Get the distances between the pairs              ##
    ######################################################
    print(count_zero)
    print(count_ones)
  
    for i in range(count_zero):
        for j in range(i+1, count_zero):
            dist = np.sqrt(np.sum((zeros[i] - zeros[j])**2))
            distances_gen_0.append(dist)
#     
    print("hi")
    
#     plt.hist(distances_gen_0, bins=17073424)
#     plt.title('Distances between true 0s')
#     plt.xlabel('Distances')
#     plt.ylabel('Frequency')
        
#     for k in range(count_ones):
#         for l in range(i+1, count_ones):
#             dist = np.sqrt(np.sum((ones[k] - ones[l])**2))
#             distances_gen_1.append(dist)
#     print distances_gen_1
    
#     plt.hist(distances_gen_1, bins=(len(distances_gen_1)**2))
#     plt.title('Distances between true 1s')
#     plt.xlabel('Distances')
#     plt.ylabel('Frequency')
# Out:
# 4132
# 4684
# hi

# %%
plt.hist(distances_gen_0, bins=50)
plt.title('Distances between true 0s')
plt.xlabel('Distances')
plt.ylabel('Frequency')
# Out:
# 1358.3188138283294
# Text(0, 0.5, 'Frequency')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
import sys


zeros = []
ones = []
distances_gen_0 = []
distances_gen_1 = []
count_zero = 0
count_ones = 0

with open("train.csv") as f:

# skip the line
    next(f)
    # parse and convert to int list
    for line in f:
        arr = []
        pixels = []
        matrix = line.split(',')
        ######################################################
        #### Get the digit and the vector of pixel values ####
        ######################################################
        
        if matrix[0] == '0':
            for x in matrix:
                x = x.split('\r\n')
                for p in x:
                    if p != '':
                        arr.append(int(p))
            digit = arr[0]
            pixel = np.array(arr[1:])
            zeros.append(pixel)
            count_zero = count_zero + 1
            
        if matrix[0] == '1':
            for x in matrix:
                x = x.split('\r\n')
                for p in x:
                    if p != '':
                        arr.append(int(p))
            digit = arr[0]
            pixel = np.array(arr[1:])
            ones.append(pixel)
            count_ones = count_ones + 1
        
    ######################################################
    ## Get the distances between the pairs              ##
    ######################################################
    print(count_zero)
    print(count_ones)
  
        
    for k in range(count_ones):
        for l in range(i+1, count_ones):
            dist = np.sqrt(np.sum((ones[k] - ones[l])**2))
            distances_gen_1.append(dist)
    print("hi")
    
#     plt.hist(distances_gen_1, bins=(len(distances_gen_1)**2))
#     plt.title('Distances between true 1s')
#     plt.xlabel('Distances')
#     plt.ylabel('Frequency')
# Out:
# 4132
# 4684
# hi

# %%
plt.hist(distances_gen_1, bins=(50))
plt.title('Distances between true 1s')
plt.xlabel('Distances')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
